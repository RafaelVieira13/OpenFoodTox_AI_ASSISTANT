# %%
# import libraries
import os
import chainlit as cl
from langchain import HuggingFaceHub, PromptTemplate, LLMChain
from langchain.chains import SimpleSequentialChain
import sqlite3
import re

# setting api key
os.environ['HuggingFaceHub_API_TOKEN'] = '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'

# Function to Load the LLM model and provide sql query as response
def llm_response(question, prompt):
    llm=HuggingFaceHub(repo_id="google/gemma-7b")
    llm_chain = LLMChain(llm=llm ,prompt=prompt)
    response = llm_chain.run(question)
    return response


# Defining the Prompt

template = """
Context: You are an expert in converting English questions to SQL lite queries!
The SQL database has the name OpenFoodTox_TEST.db and has the following tables:
 - Substance_Characterization with the following columns: Substance, has, Component, CASNumber, ECRefNo, MolecularFormula, and smiles.
 - Genotoxicity with the following columns: Substance, Author, Year, OutputID, Genotoxicity.
 - EFSAOUTPUTS with the following columns: Substance, OutputID, LegalBasis, Panel, Published, Title, OutputType, DOI, URL.
 - Reference_Values with the following columns: Substance, Author, Year, OutputID, Assessment, qualfier, value, unit, Population.
 - Reference_Points with the following columns: Substance, Author, Year, OutputID, Study, TestType, Species, Route, DurationDays, Endpoint, qualifier, value, unit, Effect, Toxicity

For example:
Example 1 - How many substances are available within OpenFoodTox?
The SQL command will be something like this: SELECT COUNT(DISTINCT Substance) FROM;

Example 2 - What is the CAS number of the Substance trans-3-Hexenyl hexanoate?
The SQL command will be something like this: SELECT CASNumber FROM Substance_Characterization WHERE Substance = 'trans-3-Hexenyl hexanoate';

Example 3 - How many substances are not genotoxic?
The SQL command will be something like this: SELECT COUNT(DISTINCT Substance) FROM Genotoxicity WHERE Genotoxicity = 'Negative';

Example 4 - How many substances are genotoxic?
The SQL command will be something like this: SELECT COUNT(DISTINCT Substance) FROM Genotoxicity WHERE Genotoxicity = 'Positive';

Example 5 - Is the following substance'(+)-Lupanine' genotoxic?
The SQL command will be something like this: SELECT DISTINCT Genotoxicity FROM Genotoxicity WHERE Substance = '(+)-Lupanine';

Example 6 - How many Efsa opinions are available in OpenFoodTox?
The SQL command will be something like this: SELECT COUNT(DISTINCT OutputID) FROM EFSAOUTPUTS WHERE OutputType = 'EFSA opinion';

Example 7 - How many Efsa opinions are available in OpenFoodTox for the following substance: '(-)-Alpha-elemol'?
The SQL command will be something like this: SELECT COUNT(DISTINCT OutputID) FROM EFSAOUTPUTS WHERE OutputType = 'EFSA opinion' AND Substance = '(-)-Alpha-elemol';

Example 8 - Tell me how many EFSA statements are available in OpenFoodTox?
The SQL command will be something like this: SELECT COUNT(DISTINCT OutputID) FROM EFSAOUTPUTS WHERE OutputType = 'EFSA statement';

Example 9 - What is the average reference value by each population?
The SQL command will be something like this: SELECT DISTINCT Population, AVG(value) as avg, unit FROM Reference_Values GROUP BY Population ORDER BY avg DESC;

Example 10 - What is the average reference value for the following susbtance: '(R)-(-)-Lavandulol'?
The SQL command will be something like this: SELECT AVG(value) as avg, unit FROM Reference_Values WHERE Substance='(R)-(-)-Lavandulol';

Example 11 - What is the average reference value by assessment?
The SQL command will be something like this: SELECT DISTINCT Assessment, AVG(value) as avg, unit FROM Reference_Values GROUP BY Assessment ORDER BY avg DESC;

Example 11 - Give me the average reference value by assessment for the following substance: '(Z)-Nerol'?
The SQL command will be something like this: SELECT DISTINCT Assessment, AVG(value) as avg, unit FROM Reference_Values WHERE Substance='(Z)-Nerol' GROUP BY Assessment ORDER BY avg DESC;

Example 12 - What are the reported effects for the following susbstance: '(2E)-Methylcrotonic acid' ? 
The SQL command will be something like this:SELECT DISTINCT Effect FROM REFERENCE_POINTS WHERE SUBSTANCE='(2E)-Methylcrotonic acid';

Example 13 - Tell me the average endpoint values for the following substance: '(RS)-2,4-dinitro-6-(octan-2-yl)phenyl (2 E/Z)-but-2-enoate'?
The SQL command will be something like this: SELECT Substance, Endpoint, AVG(value) AS avg, unit FROM REFERENCE_POINTS WHERE SUBSTANCE=''(RS)-2,4-dinitro-6-(octan-2-yl)phenyl (2 E/Z)-but-2-enoate' GROUP BY Endpoint ORDER BY avg DESC;

Example 14 - What is the average endpoint value by each study?
The SQL command will be something like this: SELECT Study, Endpoint, AVG(value) AS avg, unit FROM REFERENCE_POINTS GROUP BY Endpoint ORDER BY avg DESC;

Example 15 - What is the average NOEL value for the following substance: '1,1-bis(Ethylthio)-ethane'?
The SQL command will be something like this: SELECT AVG(value), unit FROM REFERENCE_POINTS WHERE Study='NOEL';

Example 16 - What is the average NOAEL value for rats?
The SQL command will be something like this: SELECT AVG(value), unit FROM REFERENCE_POINTS WHERE Study='NOAEL' AND Species='Rat';

Example 18 - What is the average LD50 value for the following study: 'Human health'?
The SQL command will be something like this: SELECT AVG(value), unit FROM REFERENCE_POINTS WHERE Study='LD50' AND Study='Human health';

Example 19 - How many studies are available for 'Human health'?
The SQL command will be something like this:SELECT COUNT (DISTINCT OutputID) FROM REFERENCE_POINTS WHERE Study = 'Human health';

Example 20 - How many EFSA outputs are available for the following study: 'Human health'?
The SQL command will be something like this:SELECT COUNT (DISTINCT OutputID) FROM REFERENCE_POINTS WHERE Study = 'Human health';

Example 21 - Within OpenFoodTox how many outputs are available for 'Animal (target species) health'?
The SQL command will be something like this:SELECT COUNT (DISTINCT OutputID) FROM REFERENCE_POINTS WHERE Study = 'Animal (target species) health';

Example 21 - Within OpenFoodTox how many outputs are available for each study?
The SQL command will be something like this:SELECT Study ,COUNT (DISTINCT OutputID) AS count FROM REFERENCE_POINTS GROUP BY Study ORDER BY count DESC;


Also, the SQL command should not have ' and the () at the beginning or at the end of the SQL word in the output.Your output should be just the SQL command. 
For example:
If I ask you 'What is the CAS number of the Substance trans-3-Hexenyl hexanoate?' Your output must be just the SQL command, like this:  SELECT CASNumber FROM Substance_Characterization WHERE Substance = 'trans-3-Hexenyl hexanoate'.
Don't Say anything else!!!!!


Question: {query}

SQL QUERY: """

prompt = PromptTemplate(input_variables=['query'],
                                       template = template)


# Function to retrieve query from the SQL database
def read_sql_query(sql, db):
    print(sql)  # Print the SQL query before executing
    
    conn = sqlite3.connect(db)
    cur = conn.cursor()
    cur.execute(sql)
    rows = cur.fetchall()
    conn.commit()
    conn.close()
    
    print("Query result:")
    for row in rows:
        print(row)
    
    return rows


#### Testing The Model ####

# Questions
questions = ["How many substances are available within the OpenFoodTox database?",
             "Within OpenFoodTox how many substances have a CASnumber?",
             "What is the CASnumber for the following substance '(+)-13alpha-Tigloyloxylupanine'?",
             "What is the  CASnumber for the following substance '(-)-alpha-Santalene'?",
             "What is the CASnumber for the following substance '(2E)-3-(2-Anilino-6-methyl-4-pyrimidinyl)-2-propen-1-ol'?",
             "What is the substance name from the following CASnumber: 110-44-1' ? ",
             "What is the substance name from the following CASnumber: 19342-01-9' ?",
             "What is the molecular formula from the following CASnumber: 6119-92-2 ? ",
             "What are the smiles from the following CASnumber: 1113-21-9?",
             "What are the smiles from the following CASnumber: 110235-47-7?",
             "What are the smiles from the following Substance: (+)-Alpha-cedrene?",
             #"What are the ECRefNo for the following Substance: (2E,7R,11R)-Phytol ?",
             "What is the Substance name of the following smiles: C[C@@H](CCC[C@@H](C)CCC/C(=C/COC(=O)C)/C)CCCC(C)C ?",
             "Regarding the 2,3,4,6-Tetrachloro-5-cyanobenzamide substance what is it's component and smiles? ",
             "Tell me the cas number of the following substance: 1,2,3-Trimethoxybenzene",
             "How many substances are genotoxic?",
             "Is the following substance'(+)-Lupanine' genotoxic?",
             "Is the following substance genotoxic '(-)-Bornyl acetate'?",
             "How many substances are not genotoxic?",
             "How many substances are genotoxic?",
             "Give me a list with all the genotoxic substances",
             "How many Efsa opinions are available in OpenFoodTox?",
             "How many Efsa opinions are available in OpenFoodTox for the following substance: '3,5,6-Trichloro-2-pyridinol'?",
             "How many Efsa statements are available in OpenFoodTox for the following substance: '3,5,6-Trichloro-2-pyridinol'?",
             "What is the average reference value by each population?",
             "What is the average reference value for the following susbtance: '1-Ethoxy-1-(3-hexenyloxy)ethane'?",
             "What is the average reference value by assessment for the following substance: '(R)-(-)-Lavandulol'?",
             "Tell me the average reference value for consumers population",
             "What are the reported effects for the following susbstance: '1,3-Dichloropropene' ?",
             "Which one is the substance with the highest reference value?",
             "Tell me the average endpoint values for the following substance: '(S)-1-(3-(((4-amino-2,2-dioxido-1H-benzo[c][1,2,6]thiadiazin-5-yl)oxy)methyl)piperidin-1- yl)-3-methylbutan-1-one'?",
             "Within OpenFoodTox how many outputs are available for each study?",
             "How many EFSA outputs are available for the following study: 'Human health'?",
             "How many studies are available for 'Ecotox (soil compartment)'?"]

# Function to apply the model
def testing_model(question, prompt):
    llm_result = llm_response(question, prompt)

    # Using Regex to get just the Answer, which contains the sql command
    match = re.search(r'SQL QUERY:\s*(.*)', llm_result, re.MULTILINE)
    if match:
        sql_command = match.group(1).strip()
    else:
        print("No answer found.")

    # Using the sql_command on the read_sql_query
    data = read_sql_query(sql_command, "OpenFoodTox_TEST.db")
    return data


# Apllying the  function on each question
for question in questions:
    print(question)
    testing_model(question, prompt)
    print('')
# Out:
# How many substances are available within the OpenFoodTox database?
# SELECT COUNT(DISTINCT Substance) FROM Substance_Characterization;
# Query result:
# (5146,)
#
# Within OpenFoodTox how many substances have a CASnumber?
# SELECT COUNT(DISTINCT Substance) FROM Substance_Characterization WHERE CASNumber IS NOT NULL;
# Query result:
# (4690,)
#
# What is the CASnumber for the following substance '(+)-13alpha-Tigloyloxylupanine'?
# SELECT CASNumber FROM Substance_Characterization WHERE Substance = '(+)-13alpha-Tigloyloxylupanine';
# Query result:
# ('57943-34-7',)
#
# What is the  CASnumber for the following substance '(-)-alpha-Santalene'?
# SELECT CASNumber FROM Substance_Characterization WHERE Substance = '(-)-alpha-Santalene';
# Query result:
# ('512-61-8',)
#
# What is the CASnumber for the following substance '(2E)-3-(2-Anilino-6-methyl-4-pyrimidinyl)-2-propen-1-ol'?
# SELECT CASNumber FROM Substance_Characterization WHERE Substance = '(2E)-3-(2-Anilino-6-methyl-4-pyrimidinyl)-2-propen-1-ol';
# Query result:
# (None,)
# ('110235-47-7',)
#
# What is the substance name from the following CASnumber: 110-44-1' ?
# SELECT Substance FROM Substance_Characterization WHERE CASNumber = '110-44-1';
# Query result:
# ('(E,E)-Hexa-2,4-dienoic acid',)
# ('AviPlus',)
#
# What is the substance name from the following CASnumber: 19342-01-9' ?
# SELECT Substance FROM Substance_Characterization WHERE CASNumber = '19342-01-9';
# Query result:
# ('(R)-N,N-Dimethylphenethylamine',)
#
# What is the molecular formula from the following CASnumber: 6119-92-2 ?
# SELECT MolecularFormula FROM Substance_Characterization WHERE CASNumber = '6119-92-2';
# Query result:
# ('C18H24N2O6',)
# ('C18H24N2O6',)
#
# What are the smiles from the following CASnumber: 1113-21-9?
# SELECT smiles FROM Substance_Characterization WHERE CASNumber = '1113-21-9';
# Query result:
# ('CC(=CCC\\C(=C\\CC\\C(=C\\CCC(C)(O)C=C)\\C)\\C)C',)
#
# What are the smiles from the following CASnumber: 110235-47-7?
# SELECT smiles FROM Substance_Characterization WHERE CASNumber = '110235-47-7';
# Query result:
# ('CC#CC1=CC(=NC(=N1)NC2=CC=CC=C2)C',)
# ('CC#CC1=CC(=NC(=N1)NC2=CC=CC=C2)C',)
# ('CC#CC1=CC(=NC(=N1)NC2=CC=CC=C2)C',)
# ('CC#CC1=CC(=NC(=N1)NC2=CC=CC=C2)C',)
# ('CC#CC1=CC(=NC(=N1)NC2=CC=CC=C2)C',)
#
# What are the smiles from the following Substance: (+)-Alpha-cedrene?
# SELECT smiles FROM Substance_Characterization WHERE Substance = '(+)-Alpha-cedrene';
# Query result:
# ('CC1=CCC23C[C@H]1C(C)(C)[C@H]3CC[C@@H]2C',)
#
# What is the Substance name of the following smiles: C[C@@H](CCC[C@@H](C)CCC/C(=C/COC(=O)C)/C)CCCC(C)C ?
# SELECT Substance FROM Substance_Characterization WHERE smiles = 'C[C@@H](CCC[C@@H](C)CCC/C(=C/COC(=O)C)/C)CCCC(C)C';
# Query result:
# ('(2E,7R,11R)-Phytyl acetate',)
#
# Regarding the 2,3,4,6-Tetrachloro-5-cyanobenzamide substance what is it's component and smiles?
# SELECT Component, smiles FROM Substance_Characterization WHERE Substance = '2,3,4,6-Tetrachloro-5-cyanobenzamide';
# Query result:
# ('2,3,4,6-Tetrachloro-5-cyanobenzamide', 'Clc1c(C(N)=O)c(Cl)c(C#N)c(Cl)c1Cl')
# ('Chlorothalonil', 'Clc1c(Cl)c(C#N)c(Cl)c(C#N)c1Cl')
#
# Tell me the cas number of the following substance: 1,2,3-Trimethoxybenzene
# SELECT CASNumber FROM Substance_Characterization WHERE Substance = '1,2,3-Trimethoxybenzene';
# Query result:
# ('634-36-6',)
#
# How many substances are genotoxic?
# SELECT COUNT(DISTINCT Substance) FROM Genotoxicity WHERE Genotoxicity = 'Positive';
# Query result:
# (189,)
#
# Is the following substance'(+)-Lupanine' genotoxic?
# SELECT DISTINCT Genotoxicity FROM Genotoxicity WHERE Substance = '(+)-Lupanine';
# Query result:
# ('Negative',)
#
# Is the following substance genotoxic '(-)-Bornyl acetate'?
# SELECT Genotoxicity FROM Genotoxicity WHERE Substance = '(-)-Bornyl acetate';
# Query result:
# ('Not determined',)
# ('Not determined',)
#
# How many substances are not genotoxic?
# SELECT COUNT(DISTINCT Substance) FROM Genotoxicity WHERE Genotoxicity = 'Negative';
# Query result:
# (2820,)
#
# How many substances are genotoxic?
# SELECT COUNT(DISTINCT Substance) FROM Genotoxicity WHERE Genotoxicity = 'Positive';
# Query result:
# (189,)
#
# Give me a list with all the genotoxic substances
# SELECT DISTINCT Substance FROM Genotoxicity WHERE Genotoxicity = 'Positive';
# Query result:
# ('1,1,1-Trichloro-2,2-bis (p-chlorophenyl) ethane',)
# ('1,2-Dimethoxy-4-(prop-1-enyl)-benzene',)
# ('1,3-Dichloropropene',)
# ('1-(2-Furyl)-propan-2-one',)
# ('1-(2-Furyl)butan-3-one',)
# ('1-(4-Methoxyphenyl)-4-methylpent-1-en-3-one',)
# ('1-(4-Methoxyphenyl)pent-1-en-3-one',)
# ('1-Chloro-2-methylpropene',)
# ('1H-benzimidazol-2-amine',)
# ("2,2',4,4',5-Pentabromodiphenyl ether",)
# ('2,2,4,4-Tetrabromodiphenyl ether',)
# ('2,4-Dimethyl-3-thiazoline',)
# ('2,6,6-Trimethyl-1-cyclohexen-1-carboxaldehyde',)
# ('2-Acetyl-3,5-dimethylfuran',)
# ('2-Acetyl-5-methylfuran',)
# ('2-Amino-1H-benzimidazol-4-ol',)
# ('2-Butylfuran',)
# ('2-Butyrylfuran',)
# ('2-Decylfuran',)
# ('2-Heptylfuran',)
# ('2-Hexanoylfuran',)
# ('2-Isobutyl-3-thiazoline',)
# ('2-Methyl-2-thiazoline',)
# ('2-Methylbuta-1,3-diene',)
# ('2-Methylthiazolidine',)
# ('2-Pentanoylfuran',)
# ('2-Pentylfuran',)
# ('2-Propylthiazolidine',)
# ('3-Acetyl-2,5-dimethylfuran',)
# ('3-Acetyl-2,5-dimethylthiophene',)
# ('3-Chloro-2-methylpropene',)
# ('3-Methyl-2/(3-methylbut-2-enyl)furan',)
# ('4,5-Epoxydec-2(trans)-enal',)
# ('4-Chloroaniline',)
# ('5-Acetyl-2,3-dihydro-1,4-thiazine',)
# ('5-Methylchrysene',)
# ('6-Acetyl-2,3-dihydro-1,4-thiazine',)
# ('6-Methylquinoline',)
# ('Acid Red 73',)
# ('Acrylamide',)
# ('Aflatoxin B1',)
# ('Aflatoxin M1',)
# ('Aflatoxins (sum of B1, B2, G1, G2)',)
# ('Aflatoxins (sum of B1, B2, G1, G2, M1)',)
# ('Alternariol',)
# ('Alternariol monomethyl ether',)
# ('Ammonium monovanadate',)
# ('Arsenic, inorganic derivates',)
# ('Auramine',)
# ('Basic cobaltous carbonate monohydrate',)
# ('Benzene',)
# ('Benzo[a]pyrene',)
# ('Benzo[j]fluoranthene',)
# ('Bisglycinato oxo vanadium',)
# ('Bismaltolato oxo vanadium',)
# ('Brevetoxin 2',)
# ('Brevetoxin 3',)
# ('Brevetoxin 6',)
# ('Brevetoxin 9',)
# ('Bromomethane',)
# ('Butter Yellow',)
# ('Cadmium (total)',)
# ('Carbendazim',)
# ('Chromium (VI)',)
# ('Cis-2-butene-1,4-dial',)
# ('Citrinin',)
# ('Cobalt acetate tetrahydrate',)
# ('Cobalt carbonate 46%',)
# ('Cobalt sulphate heptahydrate',)
# ('Cobalt(II) chloride hexahydrate',)
# ('Cobalt(II) derivatives',)
# ('Congo Red',)
# ('Copper (total)',)
# ('Cyclopenta[cd]pyrene',)
# ('Decabromobiphenyl ether',)
# ('Dibenzo[a,e]pyrene',)
# ('Dibenzo[a,h]pyrene',)
# ('Dibenzo[a,i]pyrene',)
# ('Dibenzo[a,l]pyrene',)
# ('Dibromoneopentyl glycol',)
# ('Dibutyltin',)
# ('Difurfuryl ether',)
# ('Ethyl carbamate',)
# ('Ethyl furfuryl ether',)
# ('Fluoride',)
# ('Formaldehyde',)
# ('Furaltadone',)
# ('Furan',)
# ('Furan-2(5H)-one',)
# ('Furazolidone',)
# ('Furfuryl methyl ether',)
# ('Gentian tincture (Gentiana lutea L.)',)
# ('Glycidamide',)
# ('Glycidol',)
# ('Heliotridines',)
# ('Hexachlorobenzene',)
# ('Hydroquinone',)
# ('Lasiocarpine',)
# ('Leucomalachite Green',)
# ('Malachite Green',)
# ('Metanil Yellow',)
# ('Methyl (5-hydroxy-1H-benzimidazol-2-yl)carbamate',)
# ('Methyl [(2-aminophenyl)carbamothioyl] carbamate',)
# ('Methyl eugenol',)
# ('Methylmercury',)
# ('Mineral oil aromatic hydrocarbons',)
# ('Morphine',)
# ('Myrtenal',)
# ('Myrtenol',)
# ('Myrtenyl acetate',)
# ('Myrtenyl formate',)
# ('Myrtenyl-2-methylbutyrate',)
# ('Myrtenyl-3-methylbutyrate',)
# ('N-Nitroso-(2-aminoethyl)ethanolamine',)
# ('N-nitrosamines',)
# ('N-nitrosodi-n-propylamine',)
# ('N-nitrosodibutylamine',)
# ('N-nitrosodiethylamine',)
# ('N-nitrosodimethylamine',)
# ('N-nitrosomethylethylamine',)
# ('N-nitrosomorpholine',)
# ('N-nitrosopiperidine',)
# ('N-nitrosopyrrolidine',)
# ('Nickel (total)',)
# ('Nitrofurantoin',)
# ('Ochratoxin A',)
# ('Oil Orange SS',)
# ('Okadaic acid',)
# ('Omethoate',)
# ('Otonecines',)
# ('PAH2',)
# ('PAH4',)
# ('PAH8',)
# ('PCB-153',)
# ('Para Red',)
# ('Pentan-2,4-dione',)
# ('Phomopsin A',)
# ('Phosalone impurity (AE F073749/RPA 590184)',)
# ('Polychlorinated biphenyls, non dioxin-like (NDL-PCBs)',)
# ('Ponceau 3R',)
# ('Ponceau MX',)
# ('Pyrrolizidine alkaloids',)
# ('Retronecines',)
# ('Rhodamine B',)
# ('Riddelliine',)
# ('Smoke Flavouring FF-B',)
# ('Sterigmatocystin',)
# ('Sudan I',)
# ('Sudan II',)
# ('Sudan III',)
# ('Sudan IV',)
# ('Sudan Red 7B',)
# ('T-2 and HT-2 toxins',)
# ('T-2 toxin',)
# ('Thiophanate-methyl',)
# ('Thiophanate-methyl metabolite (4-OH-TM)',)
# ('Thiophanate-methyl metabolite (5-OH-MBC-S)',)
# ('Thiophanate-methyl metabolite (AV-1951)',)
# ('Thiophanate-methyl metabolite (DX-105)',)
# ('Thiophanate-methyl metabolite (FH-432)',)
# ('Tris(2,3-dibromopropyl) phosphate',)
# ('Uranium (total)',)
# ('Vanadium (total)',)
# ('Vanadium citrate',)
# ('Vanadium pentoxide',)
# ('Vanillylidene acetone',)
# ('Zearalanone',)
# ('Zearalanone glucopyranosides and sulfates',)
# ('Zearalenone',)
# ('Zearalenone and its phase I/II metabolites',)
# ('Zearalenone glucopyranosides and sulfates',)
# ('[3-(2,3-epoxypropoxy) propyl]trimethoxy silane',)
# ('alpha-Zearalanol',)
# ('alpha-Zearalanol glucopyranosides and sulfates',)
# ('alpha-Zearalenol',)
# ('alpha-Zearalenol glucopyranosides and sulfates',)
# ('beta-Zearalanol',)
# ('beta-Zearalanol glucopyranosides and sulfates',)
# ('beta-Zearalenol',)
# ('beta-Zearalenol glucopyranosides and sulfates',)
# ('cis-Zearalenone',)
# ('cis-Zearalenone glucopyranosides and sulfates',)
# ('cis-alpha-Zearalenol',)
# ('cis-alpha-Zearalenol glucopyranosides and sulfates',)
# ('cis-beta-Zearalenol',)
# ('cis-beta-Zearalenol glucopyranosides and sulfates',)
# ('p-Mentha-1,8-dien-7-al',)
# ('p-Mentha-1,8-dien-7-ol',)
# ('p-Mentha-1,8-dien-7-yl acetate',)
#
# How many Efsa opinions are available in OpenFoodTox?
# SELECT COUNT(DISTINCT OutputID) FROM EFSAOUTPUTS WHERE OutputType = 'EFSA opinion';
# Query result:
# (1591,)
#
# How many Efsa opinions are available in OpenFoodTox for the following substance: '3,5,6-Trichloro-2-pyridinol'?
# SELECT COUNT(DISTINCT OutputID) FROM EFSAOUTPUTS WHERE OutputType = 'EFSA opinion' AND Substance = '3,5,6-Trichloro-2-pyridinol';
# Query result:
# (0,)
#
# How many Efsa statements are available in OpenFoodTox for the following substance: '3,5,6-Trichloro-2-pyridinol'?
# SELECT COUNT(DISTINCT OutputID) FROM EFSAOUTPUTS WHERE OutputType = 'EFSA statement' AND Substance = '3,5,6-Trichloro-2-pyridinol';
# Query result:
# (3,)
#
# What is the average reference value by each population?
# SELECT DISTINCT Population, AVG(value) as avg, unit FROM Reference_Values GROUP BY Population ORDER BY avg DESC;
# Query result:
# ('Turkeys for meat production, less than 1 year old', 20000000.0, 'IU/g')
# ('Chicken for egg production, less than 1 year old', 20000000.0, 'IU/g')
# ('Chicken broilers, less than 1 year old', 20000000.0, 'IU/g')
# ('Turkey for reproduction', 10000000.0, 'IU/g')
# ('Cattle for milk production', 162811.11286486487, 'mg/kg')
# ('Cattle for meat production - less than 1 year old', 135237.42583783786, 'mg/kg')
# ('Pigs - less than 1 year old', 83878.41580310882, 'mg/kg')
# ('Pigs for reproduction', 67246.64427777778, 'mg/kg')
# ('Chicken for egg production', 52994.33238095238, 'mg/kg')
# ('Cattle for meat production', 50576.89527363184, 'mg/kg')
# ('Turkeys for meat production', 49542.575643564356, 'mg/kg')
# ('Chicken for meat production', 45479.221809954746, 'mg/kg')
# ('Pigs for meat production', 34241.32, 'mg/kg')
# ('Young cattle of less than 1 year of age', 15000.0, 'mg/kg')
# ('Ruminants - unspecified', 14667.553333333333, 'mg/kg')
# ('Cattle for reproduction', 5000.0, 'mg/kg')
# ('Soil macroorganisms - earthworms', 4572.857142857143, 'µg/kg')
# ('Fish', 3249.387870967742, 'mg/kg')
# ('Aquatic animal for food production - unspecified', 2916.072727272727, 'mg/kg')
# ('Animal for food production - unspecified', 2533.6640625, 'mg/kg')
# ('Cattle for milk production - adults', 2313.311111111111, 'mg/day')
# ('Aquatic compartment', 2158.497288659794, 'µg/L')
# ('Pigs for meat production - less than 1 year old', 2116.90625, 'mg/kg')
# ('Pigs', 1816.9359550561796, 'mg/kg')
# ('Aquatic animal not used for food production - unspecified', 1696.7654320987654, 'mg/kg')
# ('Cattle for meat production - adults', 1502.6235294117646, 'mg/day')
# ('Consumers - Pregnant women 18-24 years', 1453.3333333333333, 'mg/day')
# ('Consumers - Lactating women 18-24 years', 1453.3333333333333, 'mg/day')
# ('Consumers - Adults 18-24 years', 1453.3333333333333, 'mg/day')
# ('Consumers - Pregnant women >= 25 years', 1400.0, 'mg/day')
# ('Consumers - Lactating women >= 25 years', 1400.0, 'mg/day')
# ('Consumers - Adults >= 25 years', 1400.0, 'mg/day')
# ('Soil compartment', 1350.4807826086956, 'µg/kg')
# ('Terrestrial Plants', 1117.5, 'µg/kg')
# ('Trouts', 1039.875, 'mg/kg')
# ('Animal not used for food production - unspecified', 1011.4938938053098, 'mg/kg')
# ('Consumers - Premenopausal women', 1007.6666666666666, 'mg/day')
# ('Pigs for reproduction - adults', 796.6625, 'mg/day')
# ('Dogs as pet', 707.7350216450217, 'mg/kg')
# ('Cats as pet', 694.2544782608695, 'mg/kg')
# ('Poultry', 686.9508379888268, 'mg/kg')
# ('Equines', 500.0, 'mg/kg')
# ('Consumers - Children 4-10 years', 481.0, 'mg/day')
# ('Consumers - Adults', 462.92949382716046, 'µg/day')
# ('Pigs for meat production - adults', 398.4125, 'mg/day')
# ('Consumers - Infants', 370.04, 'mg/L')
# ('Rodents', 334.0, 'mg/kg')
# ('Consumers - Children 11-17 years', 321.82222222222225, 'mg/day')
# ('Consumers - Lactating women >= 18 years', 289.9098333333333, 'mg/day')
# ('Consumers - Adult women, lactating', 287.455, 'mg/kg bw/day')
# ('Salmons', 280.00074303405574, 'mg/kg')
# ('Consumers - Children 10-17 years', 266.6666666666667, 'mg/day')
# ('Consumers - Adult women, pregnant', 265.32161538461537, 'mg/kg bw/day')
# ('Consumers - Children 15-17 years', 258.24744, 'mg/day')
# ('Consumers - Pregnant women >= 18 years', 256.386347826087, 'mg/day')
# ('Consumers - Children 4-9 years', 250.0, 'mg/day')
# ('Consumers - Children 3-9 years', 230.0, 'mg/day')
# ('Goat', 225.27777777777777, 'mg/kg')
# ('Consumers - Children 11-14 years', 216.40647619047618, 'mg/day')
# ('Sheep', 213.4090909090909, 'mg/kg')
# ('Consumers - Adults >=18 years', 201.68155555555555, 'mg/day')
# ('Cattle for milk production - less than 1 year old', 200.0, 'mg/kg')
# ('Consumers - Children 7-10 years', 166.87897297297297, 'mg/day')
# ('Cattle for reproduction - less than 1 year old', 105.0, 'mg/kg')
# ('Consumers - Children 4-6 years', 101.08572727272727, 'mg/day')
# ('Consumers - Children 1-3 years', 101.05283720930233, 'mg/day')
# ('Turkeys', 100.0, None)
# ('Consumers - Children', 91.94481428571429, 'mg/L')
# ('Bird', 81.5, 'mg/kg')
# ('Consumers - Adolescents', 80.0, 'µg/day')
# ('Rabbits', 66.2, 'mg/kg')
# ('Consumers - Infants 7-11 months', 64.62945454545455, 'mg/day')
# ('Consumers - Children 1-2 years', 55.54, 'mg/day')
# ('Rabbits for meat production', 53.0, 'mg/kg')
# ('Cattle', 51.53556962025316, 'mg/kg')
# ('Consumers - Children 1-10 years', 50.0, 'µg/day')
# ('Consumers - Children 7-9 years', 43.25, 'mg/day')
# ('Horse', 38.372, 'mg/kg')
# ('Consumers - Infants 6-12 months', 35.0, 'µg/day')
# ('Consumers - Children 3 years', 32.75, 'mg/day')
# ('Consumers - Children 10 years', 31.566666666666666, 'mg/day')
# ('Chicken for egg production - adults', 26.78, 'µg/kg')
# ('Consumers - Infants 0-6 months', 25.0, 'µg/day')
# ('Consumers - Infants 0-12 months', 25.0, 'µg/day')
# ('Consumers', 23.398368942179538, 'µg/kg bw/day')
# ('Consumers - Toddlers', 17.092857142857145, 'g/day')
# ('Consumers - Children 12-17 years', 9.75, 'mg/day')
# ('Consumers - Children 7-11 years', 9.5, 'mg/day')
# ('Consumers - Postmenopausal women', 8.5, 'mg/day')
# ('Consumers - Children 1-6 years', 6.0, 'mg/day')
# ('Sheep for milk production', 5.0, 'mg/kg bw/day')
# ('Sheep for meat production', 5.0, 'mg/kg bw/day')
# ('Consumers - Children 9-10 years', 2.6333333333333333, 'mg/day')
# ('Consumers - Children 7-8 years', 1.8, 'mg/day')
# ('Guinea-fowl', 1.1, 'mg/kg')
# ('Operators', 0.4, 'mg/m³')
# ('Workers', 0.21801345070422537, 'mg/kg bw/day')
# ('Residents and bystanders', 0.2, 'mg/m³')
# ('Consumers - Children 1-8 years', 0.1, 'mg/kg bw/day')
#
# What is the average reference value for the following susbtance: '1-Ethoxy-1-(3-hexenyloxy)ethane'?
# SELECT AVG(value) as avg, unit FROM Reference_Values WHERE Substance='1-Ethoxy-1-(3-hexenyloxy)ethane';
# Query result:
# (31.8, 'µg/kg bw/day')
#
# What is the average reference value by assessment for the following substance: '(R)-(-)-Lavandulol'?
# SELECT DISTINCT Assessment, AVG(value) as avg, unit FROM Reference_Values WHERE Substance='(R)-(-)-Lavandulol' GROUP BY Assessment ORDER BY avg DESC;
# Query result:
# ('TTC Cramer Class I', 30.0, 'µg/kg bw/day')
#
# Tell me the average reference value for consumers population
# SELECT DISTINCT Population, AVG(value) as avg, unit FROM Reference_Values WHERE Population = 'Consumers' GROUP BY Population ORDER BY avg DESC;
# Query result:
# ('Consumers', 23.398368942179538, 'µg/kg bw/day')
#
# What are the reported effects for the following susbstance: '1,3-Dichloropropene' ?
# SELECT DISTINCT Effect FROM REFERENCE_POINTS WHERE SUBSTANCE='1,3-Dichloropropene';
# Query result:
# ('mortality',)
# ('not reported',)
# ('reproduction',)
# ('frond number',)
# ('growth',)
# ('histopathology neoplastic',)
# ('other',)
# ('histopathology non neoplastic',)
#
# Which one is the substance with the highest reference value?
# SELECT Substance, value, unit FROM Reference_Values ORDER BY value DESC LIMIT 1;
# Query result:
# ('Vitamin A', 25000000.0, 'IU/g')
#
# Tell me the average endpoint values for the following substance: '(S)-1-(3-(((4-amino-2,2-dioxido-1H-benzo[c][1,2,6]thiadiazin-5-yl)oxy)methyl)piperidin-1- yl)-3-methylbutan-1-one'?
# SELECT Substance, Endpoint, AVG(value) AS avg, unit FROM REFERENCE_POINTS WHERE SUBSTANCE='(S)-1-(3-(((4-amino-2,2-dioxido-1H-benzo[c][1,2,6]thiadiazin-5-yl)oxy)methyl)piperidin-1- yl)-3-methylbutan-1-one' GROUP BY Endpoint ORDER BY avg DESC;
# Query result:
# ('(S)-1-(3-(((4-amino-2,2-dioxido-1H-benzo[c][1,2,6]thiadiazin-5-yl)oxy)methyl)piperidin-1- yl)-3-methylbutan-1-one', 'NOAEL', 550.0, 'mg/kg bw/day')
#
# Within OpenFoodTox how many outputs are available for each study?
# SELECT Study ,COUNT (DISTINCT OutputID) AS count FROM REFERENCE_POINTS GROUP BY Study ORDER BY count DESC;
# Query result:
# ('Human health', 974)
# ('Animal (non-target species) health', 490)
# ('Ecotox (water compartment)', 484)
# ('Ecotox (soil compartment)', 467)
# ('Animal (target species) health', 168)
#
# How many EFSA outputs are available for the following study: 'Human health'?
# SELECT COUNT (DISTINCT OutputID) FROM REFERENCE_POINTS WHERE Study = 'Human health';
# Query result:
# (974,)
#
# How many studies are available for 'Ecotox (soil compartment)'?
# SELECT COUNT(DISTINCT Study) FROM Reference_Points WHERE Study = 'Ecotox (soil compartment)';
# Query result:
# (1,)
